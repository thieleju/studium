# %% [markdown]
# # Übung 1 vom 12.10.2022

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

str = "hello world"

print(str)
# Out:
# hello world

# %%
# Generate test data array
min = 0
max = 10
step = 0.1
x = np.arange(min, max, step)

# Function
y = 2*np.sin(x)

# Plot function
plt.plot(y)
plt.show()
