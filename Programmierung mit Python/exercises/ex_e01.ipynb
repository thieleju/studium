# %% [markdown]
# # **Übung 1** Programmierung mit Python mit Anwendungen aus dem Maschinellen Lernen

# %% [markdown]
# ## Aufgabe 1
# Die erste Aufgabe beschäftigt sich mit Strings und Listen.

# %% [markdown]
# Aufgabe 1.1 (Strings) | Folgen Sie der Beschreibung des Textes in der ersten Zelle.

# %%
long_string = '''
Dieser Kurs beschäftigt sich unter anderem mit
Themen aus dem Bereich des 'Maschinellen Lernens'.
Elementar dafür sind die Datensätze, auf denen
Algorithmen veranschaulicht werden können.
Folgend sind einige Links zu Datensätze aufgelistet:

https://archive.ics.uci.edu/ml/datasets/Iris
https://archive.ics.uci.edu/ml/datasets/Auto+MPG
https://archive.ics.uci.edu/ml/datasets/Flags

Bevor sich der Kurs einigen Grundlagen des
'Maschinellen Lernens' widmet, sollen Sie sich 
zunächst mit der Programmiersprache Python 
vertraut machen.

Schreiben Sie zuerst den gesamten Inhalt dieses mehrzeiligen
Kommentars in eine Variable mit dem Namen 'long_string'.
Hinweis: Python selbst unterstützt gar keine
mehrzeiligen Kommentare. ¯\_(ツ)_/¯
'''

# %% [markdown]
# Aufgabe 1.2 (Strings) | Wie viele Zeichen stehen in der Variablen `long_string`

# %%
long_string_length = len(long_string)
print(long_string_length)
# Out:
# 735

# %% [markdown]
# Aufgabe 1.3 (Listen) | Schreiben Sie jede Zeile von `long_string` als Listenelement in eine neue Variable mit dem Namen `many_strings`. Am Ende jeder Zeile soll kein Zeilenumbruch (Newline) stehen.

# %%
many_strings = long_string.split("\n")
many_strings.remove('')
print(many_strings)
print(len(many_strings))
# Out:
# ['Dieser Kurs beschäftigt sich unter anderem mit', "Themen aus dem Bereich des 'Maschinellen Lernens'.", 'Elementar dafür sind die Datensätze, auf denen', 'Algorithmen veranschaulicht werden können.', 'Folgend sind einige Links zu Datensätze aufgelistet:', '', 'https://archive.ics.uci.edu/ml/datasets/Iris', 'https://archive.ics.uci.edu/ml/datasets/Auto+MPG', 'https://archive.ics.uci.edu/ml/datasets/Flags', '', 'Bevor sich der Kurs einigen Grundlagen des', "'Maschinellen Lernens' widmet, sollen Sie sich ", 'zunächst mit der Programmiersprache Python ', 'vertraut machen.', '', 'Schreiben Sie zuerst den gesamten Inhalt dieses mehrzeiligen', "Kommentars in eine Variable mit dem Namen 'long_string'.", 'Hinweis: Python selbst unterstützt gar keine', 'mehrzeiligen Kommentare. ¯\\_(ツ)_/¯', '']
# 20

# %% [markdown]
# Aufgabe 1.4 (Listen) | Schreiben Sie nun nur die Listenelemente aus `many_strings` in die Variable `dataset_links`, die *URLs* enthalten. Ermitteln Sie zunächst ohne Code zu schreiben die Nummern der relevanten Zeilen und verwenden Sie anschließend den *Slicing-Operator*.

# %%
# dataset_links = [el for el in many_strings if el.startswith("https")]
dataset_links = many_strings[6:9]
print(dataset_links)
# Out:
# ['https://archive.ics.uci.edu/ml/datasets/Iris', 'https://archive.ics.uci.edu/ml/datasets/Auto+MPG', 'https://archive.ics.uci.edu/ml/datasets/Flags']

# %% [markdown]
# Aufgabe 1.5 (Strings) | Schreiben Sie das folgende Statement so um, dass das erste Element von `dataset_links` in der Console mittels f-String ausgegeben wird.

# %%
print('Das Datenset \'' + dataset_links[1][-4:] + \
    '\' kann unter folgender URL heruntergeladen werden: \'' + dataset_links[1] + '\'') 

print(f"Das Datenset '{dataset_links[1][-4:]}' kann unter folgender URL heruntergeladen werden: '{dataset_links[1]}'")
# Out:
# Das Datenset '+MPG' kann unter folgender URL heruntergeladen werden: 'https://archive.ics.uci.edu/ml/datasets/Auto+MPG'
# Das Datenset '+MPG' kann unter folgender URL heruntergeladen werden: 'https://archive.ics.uci.edu/ml/datasets/Auto+MPG'

# %% [markdown]
# ## Aufgabe 2
# Die zweite Aufgabe beschäftigt sich mit mathematischen Operatoren. Neben `+`, `-`, `*`, `/` sind noch weitere matematische Operatoren für verschiedene Datentypen definiert.

# %% [markdown]
# Aufgabe 2.1 (Math Operators) | Berechnen Sie $7^5$ mit folgendem Operator `**`.

# %%
res_exp = 7**5
print(res_exp)
# Out:
# 16807

# %% [markdown]
# Aufgabe 2.2 (Math Operators) | $a\ mod\ b$ bezeichnet den Rest bei der Division von $a$ durch $b$. Berechnen Sie $9836754\ mod \ 1024$ mit folgendem Operator `%`.

# %%
res_mod = 9836754 % 1024
print(res_mod)
# Out:
# 210

# %% [markdown]
# Aufgabe 2.3 (Math Operators) | Rechnen Sie die Bytegröße einer Datei in eine leserliche Einheit um. Der Einheitenwert soll zwischen 1 und 1023 liegen.
# Geben Sie die Umrechnung mit zwei Nachkommastellen und unter Angabe der Einheit in der Console aus:
# ```
# Beispiel:  1:       "1.00 B"
#            1024:    "1.00 KB"
#            2537253: "2.42 MB"
# ```

# %%
file_size = 993012382724
byte_size_units = ['B', 'KB', 'MB', 'GB', 'TB', 'PB']
# Abschätzung von ln(x)/ln(1024) (Wie oft file_size durch 1024 teilbar ist, sodass der Rest gößer 1 ist.)
log1024 = int((file_size**(1/99999999)-1) * 14426949.780738586)

formatted_file_size = f"{file_size/(1024**log1024):.2f} {byte_size_units[log1024]}"

print(formatted_file_size)
# Out:
# 924.81 GB

# %% [markdown]
# ## Aufgabe 3
# Die drei Aufgabe beschäftigt sich mit Listen & Sets.

# %% [markdown]
# Aufgabe 3.1 (Listen & Sets) | Lösen Sie folgende Punkte:
# - Ermitteln Sie die Schnittmenge und die Vereinigungsmenge der beiden gegebenen Sets.
# - Geben Sie zusätzlich die Liste der deutschen Städte aus, die nicht in der Menge der europäischen Städte enthalten sind.

# %%
german_cities = {'Aschaffenburg', 'Würzburg', 'Frankfurt', 'Berlin'}
european_cities = {'London', 'Paris', 'Frankfurt', 'Berlin'}

intersection = german_cities.intersection(european_cities)
print(intersection)

union = german_cities.union(european_cities)
print(union)

diff = german_cities.difference(european_cities)
print(diff)
# Out:
# {'Frankfurt', 'Berlin'}
# {'Paris', 'Aschaffenburg', 'Berlin', 'Würzburg', 'London', 'Frankfurt'}
# {'Würzburg', 'Aschaffenburg'}

# %% [markdown]
# Aufgabe 3.2 (Listen & Sets) | Lösen Sie folgende Punkte:
# - Geben Sie die Listenelemente von `cities` zusammen mit dem Index aus.
# - Sortieren Sie die Liste `cities`. Geben Sie diese aus.
# - Fügen Sie in der Liste `cities` am Ende `'München'` hinzu.
# - Löschen Sie aus der Liste `cities` den Eintrag `'Berlin'`.
# - Sortieren Sie die Liste `cities` in umgekehrter Reihenfolge.
# - Konvertieren Sie die Liste `cities` zu einem einzelnen String und geben Sie diesen aus.

# %%
cities = ['Aschaffenburg', 'Würzburg', 'Frankfurt', 'Berlin']

print("\n".join([f"Stadt: {city} mit Index {index}" for index, city in enumerate(cities)]))
print(list(enumerate(cities)))

cities.sort()
print(cities)

cities.append('München')
print(cities)

cities.remove('Berlin')
print(cities)

cities.sort(reverse=True)
print(cities)

print(", ".join(cities))
# Out:
# Stadt: Aschaffenburg mit Index 0
# Stadt: Würzburg mit Index 1
# Stadt: Frankfurt mit Index 2
# Stadt: Berlin mit Index 3
# [(0, 'Aschaffenburg'), (1, 'Würzburg'), (2, 'Frankfurt'), (3, 'Berlin')]
# ['Aschaffenburg', 'Berlin', 'Frankfurt', 'Würzburg']
# ['Aschaffenburg', 'Berlin', 'Frankfurt', 'Würzburg', 'München']
# ['Aschaffenburg', 'Frankfurt', 'Würzburg', 'München']
# ['Würzburg', 'München', 'Frankfurt', 'Aschaffenburg']
# Würzburg, München, Frankfurt, Aschaffenburg

# %% [markdown]
# ## Playground
# Hier gibt es nochmal weiterführende Details zu Operatoren und den resultierenden Datentypen.

# %%
def printWithType(a):
    print(
        f'{a:<30} | The result is of type {type(eval(a.split(" = ")[0])).__name__}')

print('\nTest verschiedener Operatoren und den resultierenden Datentypen:')
printWithType(f'{123 + 321 = }')
printWithType(f'{1 - 0.0 = }')
printWithType(f'{-0 + 1 = }')
printWithType(f'{3 // 2 = }')
printWithType(f'{3.2 // 2 = }')
printWithType(f'{3 % 2 = }')
printWithType(f'{3 ** 2 = }')
printWithType(f'{4 ** 0.5 = }')
printWithType(f'{"1" + "2" = }')
printWithType(f'{2 / 1 = }')

print('\nWeitere Zahlenrepräsentation und Datenformate:')
printWithType(f'{.11 = }')
printWithType(f'{11. = }')
printWithType(f'{11e+3 = }')
printWithType(f'{-.3e-3 = }')
printWithType(f'{6j = }')
printWithType(f'{0xFF = }')
printWithType(f'{0o77 = }')
printWithType(f'{0b01010101 = }')
printWithType(f'{0xA0F + 0o37 - 0b1 - 2600 = }')

print('\nBoolsche Ausdrücke in Python:')
printWithType(f'{True = }')
printWithType(f'{False = }')
printWithType(f'{bool(1.0) = }')
printWithType(f'{bool(0.1) = }')
printWithType(f'{bool(0.0) = }')
printWithType(f'{bool(0) = }')
# mit None-Values, be careful with None
printWithType(f'{bool(None) = }')
printWithType(f'{None == False = }') # be careful with None
printWithType(f'{None == True = }')  # be careful with None
printWithType(f'{None == None = }')  # be careful with None
printWithType(f'{None != None = }')  # be careful with None
# mit Lists, Dicts und Sets
printWithType(f'{bool([]) = }') 
printWithType(f'{bool([False]) = }')
printWithType(f'{bool({}) = }')
printWithType(f'{bool({False}) = }') 
printWithType(f'{bool({False:False}) = }') 


print('\nSets und Dicts:')
ab = {'a', 'b'}
bc = {'b', 'c'}
printWithType(f'{ab - bc = }')
printWithType(f'{bc - ab = }')
printWithType(f'{ab | bc = }')
printWithType(f'{ab ^ bc = }')
printWithType(f'{ab & bc = }')

print('\nRepräsentation des Types Float als String:')
print(f'{1e-3}')
print(f'{1e-11}')
print(f'{1e-11:.3f}')
print(f'{1e-11:.11f}')
print(f'{0.12345678901234567890123456789}')
print(f'{0.12345678901234567890123456789:.64f}')
print(f'{1234567890.12345678901234567890123456789:.64f}')
# Out:
# Test verschiedener Operatoren und den resultierenden Datentypen:
# 123 + 321 = 444                | The result is of type int
# 1 - 0.0 = 1.0                  | The result is of type float
# -0 + 1 = 1                     | The result is of type int
# 3 // 2 = 1                     | The result is of type int
# 3.2 // 2 = 1.0                 | The result is of type float
# 3 % 2 = 1                      | The result is of type int
# 3 ** 2 = 9                     | The result is of type int
# 4 ** 0.5 = 2.0                 | The result is of type float
# "1" + "2" = '12'               | The result is of type str
# 2 / 1 = 2.0                    | The result is of type float
#
# Weitere Zahlenrepräsentation und Datenformate:
# .11 = 0.11                     | The result is of type float
# 11. = 11.0                     | The result is of type float
# 11e+3 = 11000.0                | The result is of type float
# -.3e-3 = -0.0003               | The result is of type float
# 6j = 6j                        | The result is of type complex
# 0xFF = 255                     | The result is of type int
# 0o77 = 63                      | The result is of type int
# 0b01010101 = 85                | The result is of type int
# 0xA0F + 0o37 - 0b1 - 2600 = 5  | The result is of type int
#
# Boolsche Ausdrücke in Python:
# True = True                    | The result is of type bool
# False = False                  | The result is of type bool
# bool(1.0) = True               | The result is of type bool
# bool(0.1) = True               | The result is of type bool
# bool(0.0) = False              | The result is of type bool
# bool(0) = False                | The result is of type bool
# bool(None) = False             | The result is of type bool
# None == False = False          | The result is of type bool
# None == True = False           | The result is of type bool
# None == None = True            | The result is of type bool
# None != None = False           | The result is of type bool
# bool([]) = False               | The result is of type bool
# bool([False]) = True           | The result is of type bool
# bool({}) = False               | The result is of type bool
# bool({False}) = True           | The result is of type bool
# bool({False:False}) = True     | The result is of type bool
#
# Sets und Dicts:
# ab - bc = {'a'}                | The result is of type set
# bc - ab = {'c'}                | The result is of type set
# ab | bc = {'b', 'c', 'a'}      | The result is of type set
# ab ^ bc = {'a', 'c'}           | The result is of type set
# ab & bc = {'b'}                | The result is of type set
#
# Repräsentation des Types Float als String:
# 0.001
# 1e-11
# 0.000
# 0.00000000001
# 0.12345678901234568
# 0.1234567890123456773698862320998159702867269515991210937500000000
# 1234567890.1234567165374755859375000000000000000000000000000000000000000000
