# %% [markdown]
# # **Übung 7** Programmierung mit Python mit Anwendungen aus dem Maschinellen Lernen

# %% [markdown]
# ## Aufgabe 1
# Die erste Aufgabe beschäftigt sich mit grundlegenden Funktionen des Python Packages `pandas`.
#
# Pandas ist besonders nützlich für die Analyse von Tabellendaten.
#
# Zu den wichtigsten Datenstrukturen in Pandas gehören die **DataFrame**- und **Series**-Objekte. **DataFrame**-Objekte stellen tabellarische Daten dar, die aus Zeilen und Spalten bestehen, ähnlich wie in einer Excel-Tabelle. **Series**-Objekte sind eindimensionale Datenstrukturen, die eine einzelne Spalte in einem DataFrame darstellen.

# %% [markdown]
# **Aufgabe 1.1 (pandas)** | Lesen Sie die Datei `sensor_data.csv` mit Hilfe von `pd.read_csv` ein.

# %%
# Lädt die Datei sensor_data.csv in die Colab Umgebung
# !gdown 1lzW5HFV8zS4htGDDJ6lM-v4CIfLJugj1

# Zum Anzeigen von Plots soll heute plotly verwendet werden
# !pip install plotly

import plotly.express as px

# %%
import pandas as pd
# ADD YOUR CODE

# %% [markdown]
# **Aufgabe 1.2 (pandas)** | Geben Sie die Spalten der eingelesenen Daten in der Konsole aus.

# %%
# ADD YOUR CODE

# %% [markdown]
# **Aufgabe 1.3 (pandas)** | Um einen ersten Eindruck der Daten zu erhalten, schauen Sie sich die Temperaturwerte `AverageTemperatureFahr` mittels der Methode `describe` an und erstellen Sie einen Plot der Werte.

# %%
# ADD YOUR CODE

# %% [markdown]
# **Aufgabe 1.4 (pandas)** | Geben Sie in der Konsole aus, wie viele Temperaturwerte im Datensatz zwischen 50°F und 55°F liegen.
#
# Vergleichsoperatoren (`==, !=, <, >, <=, >=`) können auf DataFrames und Series angewandt werden. Der Vergleich kann mit numerischen Konstanten oder einem DataFrame/Series-Objekt gleicher Dimensionalität erfolgen.
#
# Boolesche Spalten können mit den Bitwise `&, |` Operatoren verknüpft werden.
#
# Erwarteter Wert: `5216`

# %%
# ADD YOUR CODE

# %% [markdown]
# **Aufgabe 1.5 (pandas)** | Geben Sie in der Konsole aus, in welchen Städten Temperaturen über 79°F aufgezeichnet wurden.
# Sie können die `unique` Methode verwenden, um einzigartige Werte aus einem Series Objekt zu identifizieren.

# %%
# ADD YOUR CODE

# %% [markdown]
# **Aufgabe 1.6 (pandas)** | In Aufgabe 1.5 sollten Sie auf einen `nan`-Wert gestoßen sein. Dieser Datensatz wurde nicht bereinigt und enthält ungültige Datensätze.
#
# Verunreinigte Daten können zu Problemen in der Analyse führen und sind oft nicht direkt sichtbar.
#
# Geben Sie die Anzahl der Null-Werte (`nan`) in der Spalte `AverageTemperatureFahr` im Datensatz aus.
# Die Methode `isna` gibt `True` für Null-Werte zurück.
# Die Methode `sum` summierte einen angegebenen Datenbereich.
#
# Vergewissern Sie sich, dass diese Null-Werte (Line-Plot unterbrochen) auch im zuvor erstellten Plot sichtbar werden, wenn Sie kleinere Daten Ausschnitte anschauen.

# %%
# ADD YOUR CODE

# %% [markdown]
# **Aufgabe 1.7 (pandas)** | Löschen Sie nun alle Zeilen, in denen für die aufgelisteten Spalten Null-Werte enthalten sind und speichern Sie die bereinigten Daten in einem neuen DataFrame. Die Pandas Methode `dropna` kann dafür verwendet werden.
#
# Relevante Spalten:
# - Termperaturspalte `AverageTemperatureFahr`
# - Städte `City`
# - Länder `Country`

# %%
print(f'Before delete size is: {sensor_df.size}')
sensor_cleaned_df = pd.DataFrame()  ### ADD CODE HERE ###
print(f'After delete size is: {sensor_cleaned_df.size}')
