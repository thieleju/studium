# %% [markdown]
# # **Übung 8** Programmierung mit Python mit Anwendungen aus dem Maschinellen Lernen

# %% [markdown]
# [Einführung Neuronale Netze](https://playground.tensorflow.org/)
# - Data Pattern (linear, nicht-linear trennbar)
# - Datenset (Noise, Train/Test-Split)
# - Epoche
# - Aktivierungsfunktionen (Linear, TanH)
# - Auswirkungen der Learning Rate
# - Design Netzwerk (Größe, Breite)
# - Overfitting
# - Stabilität des Trainings

# %% [markdown]
# ## Aufgabe 1
# Die erste Aufgabe beschäftigt sich mit der Lineare Regression in PyTorch.

# %%
# Hilfsfunktionen

import plotly.express as px
import plotly.graph_objects as go
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

SAMPLES_PER_AXIS = 100

def _generate_dataset(n, m, t, s, e, with_noise=True):
    x1 = np.tile(np.linspace(s, e, SAMPLES_PER_AXIS), SAMPLES_PER_AXIS)
    x2 = np.repeat(np.linspace(s, e, SAMPLES_PER_AXIS), SAMPLES_PER_AXIS)
    r = np.sin(x1)*np.sin(x2)*3 + (np.random.random(SAMPLES_PER_AXIS*SAMPLES_PER_AXIS)-0.5)*15 if with_noise else np.zeros_like(x1)
    y = n*x1 + m*x2 + t + r

    return pd.DataFrame(np.vstack([x1, x2, y, r]).T, columns=['x1', 'x2', 'y', 'r'])


def generate_dataset(n, m, t):
    ''' f(x1,x1) = n*x1 + m*x2 + t'''

    train = _generate_dataset(n, m, t, 0, 50)
    test = _generate_dataset(n, m, t, 50, 200, with_noise=False)

    return train, test


def show_dataset(dl, title):
    SAMPLES_PER_AXIS1 = SAMPLES_PER_AXIS* int(len(dl) / (SAMPLES_PER_AXIS*SAMPLES_PER_AXIS))
    rs = lambda x: x.values.reshape(SAMPLES_PER_AXIS1,SAMPLES_PER_AXIS)

    data = [go.Surface(z=rs(dl['y']),x=rs(dl['x1']),y=rs(dl['x2']), surfacecolor=rs(dl['r'])) for ds in dl]
    fig = go.Figure(data=data)

    fig.update_layout(
        title=title, 
        autosize=True, 
        )
    
    fig.update_scenes(xaxis_title_text='x1',  
                  yaxis_title_text='x2',  
                  zaxis_title_text='y')

    fig.show()

# %% [markdown]
# **Aufgabe 1.1 (PyTorch)** | Gegeben ist ein Datensatz mit zwei Input-Parameters $x1$ und $x2$ und einem gemessenen Output-Parameter $y$
# Es ist bekannt, dass sich $y$ durch folgende Funktion bestimmt ist: $f(x1,x2) = nx1 + mx2 + t + r(x1,x2)$
#
# $r(x1,x2)$ überlagert die lineare Funktion mit einem gleichverteilten, periodischen Rauschen.
#
# Mithilfe einer Linearen Regression sollen für unbekannte $x1, x2$ paare $y$-Werte abgeschätzt werden. Im Folgenden soll eine Lineare Regression mit PyTorch durchgeführt werden. Sie können sich an den Inhalten im Videomaterial zu dieser Übung orientieren.
#
# Schauen Sie sich den gegebenen Datensatz an, der Code hierfür ist schon vorgegeben.

# %%
generated_train_df, generated_test_df = generate_dataset(n=2, m=-1, t=60)
show_dataset(generated_train_df, title='[Train] Noisy Linear Surface') 
show_dataset(generated_test_df, title='[Test] Flat Linear Surface')
show_dataset(pd.concat([generated_train_df, generated_test_df], ignore_index=True), title='[Train+Test] Combined') 


label_train_df = generated_train_df.pop("y")
generated_train_df.pop("r")
label_test_df = generated_test_df.pop("y")
_ = generated_test_df.pop("r")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Aufgabe 1.2 (PyTorch)** | Zunächst soll der Datensatz in Tensoren konvertiert werden.
# Erzeugen Sie sich die vier Variablen `X_train, y_train, X_test, y_test`
#
# ```
# Erwartete Ausgabe der gegebenen Prints:
# X_train torch.Size([10000, 2]) torch.float32 cpu
# y_train torch.Size([10000, 1]) torch.float32 cpu
# X_test  torch.Size([10000, 2]) torch.float32 cpu
# y_test  torch.Size([10000, 1]) torch.float32 cpu
# ```

# %%
import torch
import torch.nn as nn
import numpy as np
import plotly.express as px

# Daten in Tensoren konvertieren
def create_tensor(featues, label):
    X_data = torch.from_numpy(featues.values.astype(np.float32))
    y_data = torch.from_numpy(label.values.astype(np.float32))
    y_data = y_data.view(y_data.shape[0], 1)
    return X_data, y_data

X_train, y_train = create_tensor(generated_train_df, label_train_df)
X_test, y_test = create_tensor(generated_test_df, label_test_df)

print("X_train", X_train.shape, X_train.dtype, X_train.device)
print("y_train", y_train.shape, y_train.dtype, y_train.device)
print("X_test ", X_test.shape, X_test.dtype, X_test.device)
print("y_test ", y_test.shape, y_test.dtype, y_test.device)
# Out:
# X_train torch.Size([10000, 2]) torch.float32 cpu
# y_train torch.Size([10000, 1]) torch.float32 cpu
# X_test  torch.Size([10000, 2]) torch.float32 cpu
# y_test  torch.Size([10000, 1]) torch.float32 cpu

# %% [markdown]
# **Aufgabe 1.3 (PyTorch)** | Erzeugen Sie ein Modell, welches die Parameter $n,m,t$ als trainierbare Parameter enthält. Sie können hierfür die Funktion selbst modellieren oder das `torch.nn.Linear`-Modul verwenden.
#
# Weisen Sie das Modell der Variablen `model` zu.

# %%
model = nn.Linear(2, 1)

# %% [markdown]
# **Aufgabe 1.4 (PyTorch)** | Als nächstes muss eine geeignete Loss-Funktion für dieses Problem ausgewählt werden. Die Loss-Funktion ist ein Maß für den Grad der Abweichung zwischen den vorhergesagten Ausgaben des Modells und den tatsächlichen Ausgaben.
#
# Die Distanz, zwischen vorhergesagten und tatsächlichen Wert, könnte hier ein gutes Maß sein. Im Namespace `torch.nn` sind verschiedene Loss-Funktionen definiert. Wählen Sie eine aus, oder implementieren Sie diese selbst.
#
# Weisen Sie die Loss-Funktion der Variablen `loss_fn` zu.

# %%
loss_fn = nn.MSELoss()

# %% [markdown]
# **Aufgabe 1.5 (PyTorch)** | Als letztes muss ein Optimizer erstellt werden. Ein Optimizer ist ein Algorithmus, der verwendet wird, um die Parameter eines Modells auf der Grundlage der Ergebnisse der Loss-Funktion zu optimieren. Erstellen Sie eine Instanz von `torch.optim.SGD` (stochastic gradient descent). Diesem müssen Sie die Modellparameter `model.parameters()` und eine `learning_rate` übergeben.
#
# Die `learning_rate` gibt an, wie stark die Parameter durch die Gradienten beeinflusst werden. Hier gilt es, ein richtiges Maß zu finden.

# %%
learning_rate = 0.0006
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# **Aufgabe 1.6 (PyTorch)** | Trainieren Sie das erstellte Modell. In der Regel wird das Modell pro Epoche einmal mit allen Trainingsdaten trainiert. Folgende Schritte sollen in jeder Epoche durchgeführt werden.
# 1. Modellausgaben `y_pred_train`, mit Trainingsdaten `X_train`, erzeugen
# 2. Berechnen des Loss `loss_train` durch Vergleich von `y_pred_train` und `y_train`
# 3. Den Gradienten auf Basis des Loss berechnen
# 4. Modellparameter optimieren
# 5. Modellausgaben `y_pred_test`, mit Testdaten `X_test`, erzeugen
# 6. Berechnen des Loss `loss_test` durch Vergleich von `y_pred_test` und `y_test`
# 7. Gradienten zurücksetzen
#
#
# Vergleichen Sie die Modellparameter $n,m,t$

# %%
learning_rate = 0.0006
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

loss_res = []

num_epochs = 25000
plot_freq = 10
print_freq = 100

for epoch in range(num_epochs):
  y_pred_train = model(X_train)
  loss_train = loss_fn(y_pred_train, y_train)

  loss_train.backward()

  optimizer.step()

  y_pred_test = model(X_test)
  loss_test = loss_fn(y_pred_test, y_test)

  optimizer.zero_grad()

  if (epoch+1) % plot_freq == 0:
    loss_res.append([epoch, loss_train.item(), loss_test.item()])

  if (epoch+1) % print_freq == 0:
    print(f'epoch: {epoch+1}, loss_train = {loss_train.item():.4f}, loss_test = {loss_test.item():.4f}')

df = pd.DataFrame(np.array(loss_res), columns=['epoch', 'loss_test', 'loss_train'])

for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data)

fig = px.line(df, x="epoch", y=['loss_test', 'loss_train'], title='Trainingsverlauf', log_y=True)
fig.show()
# Out:
# epoch: 100, loss_train = 525.9278, loss_test = 41300.4570
# epoch: 200, loss_train = 508.6167, loss_test = 39888.2695
# epoch: 300, loss_train = 491.8988, loss_test = 38524.3828
# epoch: 400, loss_train = 475.7534, loss_test = 37207.2031
# epoch: 500, loss_train = 460.1613, loss_test = 35935.1094
# epoch: 600, loss_train = 445.1034, loss_test = 34706.5352
# epoch: 700, loss_train = 430.5613, loss_test = 33520.0195
# epoch: 800, loss_train = 416.5175, loss_test = 32374.1191
# epoch: 900, loss_train = 402.9548, loss_test = 31267.4141
# epoch: 1000, loss_train = 389.8568, loss_test = 30198.5820
# epoch: 1100, loss_train = 377.2074, loss_test = 29166.3457
# epoch: 1200, loss_train = 364.9915, loss_test = 28169.4277
# epoch: 1300, loss_train = 353.1940, loss_test = 27206.6113
# epoch: 1400, loss_train = 341.8008, loss_test = 26276.7617
# epoch: 1500, loss_train = 330.7979, loss_test = 25378.7109
# epoch: 1600, loss_train = 320.1719, loss_test = 24511.4062
# epoch: 1700, loss_train = 309.9100, loss_test = 23673.7656
# epoch: 1800, loss_train = 299.9996, loss_test = 22864.7871
# epoch: 1900, loss_train = 290.4288, loss_test = 22083.4902
# epoch: 2000, loss_train = 281.1859, loss_test = 21328.9180
# epoch: 2100, loss_train = 272.2593, loss_test = 20600.1641
# epoch: 2200, loss_train = 263.6389, loss_test = 19896.3496
# epoch: 2300, loss_train = 255.3137, loss_test = 19216.5977
# epoch: 2400, loss_train = 247.2738, loss_test = 18560.1270
# epoch: 2500, loss_train = 239.5094, loss_test = 17926.1055
# epoch: 2600, loss_train = 232.0109, loss_test = 17313.7656
# epoch: 2700, loss_train = 224.7694, loss_test = 16722.3770
# epoch: 2800, loss_train = 217.7759, loss_test = 16151.2256
# epoch: 2900, loss_train = 211.0220, loss_test = 15599.6064
# epoch: 3000, loss_train = 204.4995, loss_test = 15066.8477
# epoch: 3100, loss_train = 198.2004, loss_test = 14552.3213
# epoch: 3200, loss_train = 192.1172, loss_test = 14055.3955
# epoch: 3300, loss_train = 186.2424, loss_test = 13575.4639
# epoch: 3400, loss_train = 180.5689, loss_test = 13111.9463
# epoch: 3500, loss_train = 175.0897, loss_test = 12664.2773
# epoch: 3600, loss_train = 169.7982, loss_test = 12231.9346
# epoch: 3700, loss_train = 164.6881, loss_test = 11814.3633
# epoch: 3800, loss_train = 159.7531, loss_test = 11411.0830
# epoch: 3900, loss_train = 154.9871, loss_test = 11021.5889
# epoch: 4000, loss_train = 150.3843, loss_test = 10645.4082
# epoch: 4100, loss_train = 145.9393, loss_test = 10282.0957
# epoch: 4200, loss_train = 141.6465, loss_test = 9931.2031
# epoch: 4300, loss_train = 137.5008, loss_test = 9592.3135
# epoch: 4400, loss_train = 133.4971, loss_test = 9265.0068
# epoch: 4500, loss_train = 129.6306, loss_test = 8948.8916
# epoch: 4600, loss_train = 125.8966, loss_test = 8643.5859
# epoch: 4700, loss_train = 122.2905, loss_test = 8348.7148
# epoch: 4800, loss_train = 118.8079, loss_test = 8063.9194
# epoch: 4900, loss_train = 115.4446, loss_test = 7788.8711
# epoch: 5000, loss_train = 112.1966, loss_test = 7523.2217
# epoch: 5100, loss_train = 109.0599, loss_test = 7266.6440
# epoch: 5200, loss_train = 106.0305, loss_test = 7018.8462
# epoch: 5300, loss_train = 103.1050, loss_test = 6779.5122
# epoch: 5400, loss_train = 100.2798, loss_test = 6548.3677
# epoch: 5500, loss_train = 97.5513, loss_test = 6325.1084
# epoch: 5600, loss_train = 94.9162, loss_test = 6109.4878
# epoch: 5700, loss_train = 92.3715, loss_test = 5901.2368
# epoch: 5800, loss_train = 89.9139, loss_test = 5700.1006
# epoch: 5900, loss_train = 87.5406, loss_test = 5505.8398
# epoch: 6000, loss_train = 85.2485, loss_test = 5318.2090
# epoch: 6100, loss_train = 83.0350, loss_test = 5136.9897
# epoch: 6200, loss_train = 80.8973, loss_test = 4961.9639
# epoch: 6300, loss_train = 78.8328, loss_test = 4792.9233
# epoch: 6400, loss_train = 76.8391, loss_test = 4629.6558
# epoch: 6500, loss_train = 74.9137, loss_test = 4471.9639
# epoch: 6600, loss_train = 73.0542, loss_test = 4319.6597
# epoch: 6700, loss_train = 71.2584, loss_test = 4172.5542
# epoch: 6800, loss_train = 69.5242, loss_test = 4030.4785
# epoch: 6900, loss_train = 67.8494, loss_test = 3893.2480
# epoch: 7000, loss_train = 66.2320, loss_test = 3760.7212
# epoch: 7100, loss_train = 64.6700, loss_test = 3632.7031
# epoch: 7200, loss_train = 63.1615, loss_test = 3509.0676
# epoch: 7300, loss_train = 61.7046, loss_test = 3389.6455
# epoch: 7400, loss_train = 60.2977, loss_test = 3274.3069
# epoch: 7500, loss_train = 58.9390, loss_test = 3162.9026
# epoch: 7600, loss_train = 57.6269, loss_test = 3055.3027
# epoch: 7700, loss_train = 56.3597, loss_test = 2951.3799
# epoch: 7800, loss_train = 55.1359, loss_test = 2851.0007
# epoch: 7900, loss_train = 53.9540, loss_test = 2754.0439
# epoch: 8000, loss_train = 52.8126, loss_test = 2660.4038
# epoch: 8100, loss_train = 51.7103, loss_test = 2569.9551
# epoch: 8200, loss_train = 50.6458, loss_test = 2482.5947
# epoch: 8300, loss_train = 49.6177, loss_test = 2398.2117
# epoch: 8400, loss_train = 48.6250, loss_test = 2316.7163
# epoch: 8500, loss_train = 47.6662, loss_test = 2237.9973
# epoch: 8600, loss_train = 46.7402, loss_test = 2161.9624
# epoch: 8700, loss_train = 45.8459, loss_test = 2088.5237
# epoch: 8800, loss_train = 44.9823, loss_test = 2017.5884
# epoch: 8900, loss_train = 44.1483, loss_test = 1949.0720
# epoch: 9000, loss_train = 43.3429, loss_test = 1882.8962
# epoch: 9100, loss_train = 42.5651, loss_test = 1818.9756
# epoch: 9200, loss_train = 41.8138, loss_test = 1757.2330
# epoch: 9300, loss_train = 41.0884, loss_test = 1697.5972
# epoch: 9400, loss_train = 40.3878, loss_test = 1639.9965
# epoch: 9500, loss_train = 39.7112, loss_test = 1584.3546
# epoch: 9600, loss_train = 39.0577, loss_test = 1530.6157
# epoch: 9700, loss_train = 38.4267, loss_test = 1478.7045
# epoch: 9800, loss_train = 37.8173, loss_test = 1428.5648
# epoch: 9900, loss_train = 37.2287, loss_test = 1380.1353
# epoch: 10000, loss_train = 36.6604, loss_test = 1333.3547
# epoch: 10100, loss_train = 36.1115, loss_test = 1288.1667
# epoch: 10200, loss_train = 35.5813, loss_test = 1244.5199
# epoch: 10300, loss_train = 35.0694, loss_test = 1202.3593
# epoch: 10400, loss_train = 34.5750, loss_test = 1161.6364
# epoch: 10500, loss_train = 34.0976, loss_test = 1122.2986
# epoch: 10600, loss_train = 33.6365, loss_test = 1084.3066
# epoch: 10700, loss_train = 33.1911, loss_test = 1047.5990
# epoch: 10800, loss_train = 32.7611, loss_test = 1012.1457
# epoch: 10900, loss_train = 32.3458, loss_test = 977.9019
# epoch: 11000, loss_train = 31.9447, loss_test = 944.8210
# epoch: 11100, loss_train = 31.5573, loss_test = 912.8676
# epoch: 11200, loss_train = 31.1832, loss_test = 882.0000
# epoch: 11300, loss_train = 30.8220, loss_test = 852.1836
# epoch: 11400, loss_train = 30.4731, loss_test = 823.3858
# epoch: 11500, loss_train = 30.1362, loss_test = 795.5632
# epoch: 11600, loss_train = 29.8108, loss_test = 768.6910
# epoch: 11700, loss_train = 29.4965, loss_test = 742.7292
# epoch: 11800, loss_train = 29.1930, loss_test = 717.6506
# epoch: 11900, loss_train = 28.9000, loss_test = 693.4261
# epoch: 12000, loss_train = 28.6169, loss_test = 670.0270
# epoch: 12100, loss_train = 28.3436, loss_test = 647.4207
# epoch: 12200, loss_train = 28.0796, loss_test = 625.5856
# epoch: 12300, loss_train = 27.8247, loss_test = 604.4894
# epoch: 12400, loss_train = 27.5785, loss_test = 584.1140
# epoch: 12500, loss_train = 27.3407, loss_test = 564.4268
# epoch: 12600, loss_train = 27.1111, loss_test = 545.4135
# epoch: 12700, loss_train = 26.8894, loss_test = 527.0428
# epoch: 12800, loss_train = 26.6752, loss_test = 509.2972
# epoch: 12900, loss_train = 26.4684, loss_test = 492.1542
# epoch: 13000, loss_train = 26.2687, loss_test = 475.5923
# epoch: 13100, loss_train = 26.0758, loss_test = 459.5945
# epoch: 13200, loss_train = 25.8895, loss_test = 444.1393
# epoch: 13300, loss_train = 25.7096, loss_test = 429.2090
# epoch: 13400, loss_train = 25.5359, loss_test = 414.7848
# epoch: 13500, loss_train = 25.3681, loss_test = 400.8488
# epoch: 13600, loss_train = 25.2060, loss_test = 387.3860
# epoch: 13700, loss_train = 25.0496, loss_test = 374.3805
# epoch: 13800, loss_train = 24.8984, loss_test = 361.8163
# epoch: 13900, loss_train = 24.7525, loss_test = 349.6801
# epoch: 14000, loss_train = 24.6115, loss_test = 337.9516
# epoch: 14100, loss_train = 24.4754, loss_test = 326.6217
# epoch: 14200, loss_train = 24.3440, loss_test = 315.6759
# epoch: 14300, loss_train = 24.2170, loss_test = 305.1008
# epoch: 14400, loss_train = 24.0944, loss_test = 294.8855
# epoch: 14500, loss_train = 23.9760, loss_test = 285.0143
# epoch: 14600, loss_train = 23.8617, loss_test = 275.4770
# epoch: 14700, loss_train = 23.7512, loss_test = 266.2639
# epoch: 14800, loss_train = 23.6446, loss_test = 257.3643
# epoch: 14900, loss_train = 23.5416, loss_test = 248.7641
# epoch: 15000, loss_train = 23.4422, loss_test = 240.4541
# epoch: 15100, loss_train = 23.3461, loss_test = 232.4261
# epoch: 15200, loss_train = 23.2533, loss_test = 224.6698
# epoch: 15300, loss_train = 23.1637, loss_test = 217.1740
# epoch: 15400, loss_train = 23.0772, loss_test = 209.9343
# epoch: 15500, loss_train = 22.9937, loss_test = 202.9373
# epoch: 15600, loss_train = 22.9130, loss_test = 196.1779
# epoch: 15700, loss_train = 22.8351, loss_test = 189.6454
# epoch: 15800, loss_train = 22.7598, loss_test = 183.3340
# epoch: 15900, loss_train = 22.6871, loss_test = 177.2356
# epoch: 16000, loss_train = 22.6169, loss_test = 171.3441
# epoch: 16100, loss_train = 22.5492, loss_test = 165.6521
# epoch: 16200, loss_train = 22.4837, loss_test = 160.1512
# epoch: 16300, loss_train = 22.4205, loss_test = 154.8360
# epoch: 16400, loss_train = 22.3594, loss_test = 149.6996
# epoch: 16500, loss_train = 22.3005, loss_test = 144.7354
# epoch: 16600, loss_train = 22.2435, loss_test = 139.9403
# epoch: 16700, loss_train = 22.1885, loss_test = 135.3059
# epoch: 16800, loss_train = 22.1354, loss_test = 130.8276
# epoch: 16900, loss_train = 22.0842, loss_test = 126.5002
# epoch: 17000, loss_train = 22.0346, loss_test = 122.3184
# epoch: 17100, loss_train = 21.9868, loss_test = 118.2776
# epoch: 17200, loss_train = 21.9406, loss_test = 114.3724
# epoch: 17300, loss_train = 21.8960, loss_test = 110.5975
# epoch: 17400, loss_train = 21.8529, loss_test = 106.9520
# epoch: 17500, loss_train = 21.8113, loss_test = 103.4278
# epoch: 17600, loss_train = 21.7711, loss_test = 100.0206
# epoch: 17700, loss_train = 21.7323, loss_test = 96.7296
# epoch: 17800, loss_train = 21.6948, loss_test = 93.5489
# epoch: 17900, loss_train = 21.6586, loss_test = 90.4753
# epoch: 18000, loss_train = 21.6237, loss_test = 87.5045
# epoch: 18100, loss_train = 21.5899, loss_test = 84.6329
# epoch: 18200, loss_train = 21.5573, loss_test = 81.8579
# epoch: 18300, loss_train = 21.5259, loss_test = 79.1758
# epoch: 18400, loss_train = 21.4954, loss_test = 76.5840
# epoch: 18500, loss_train = 21.4661, loss_test = 74.0783
# epoch: 18600, loss_train = 21.4377, loss_test = 71.6563
# epoch: 18700, loss_train = 21.4103, loss_test = 69.3155
# epoch: 18800, loss_train = 21.3839, loss_test = 67.0532
# epoch: 18900, loss_train = 21.3584, loss_test = 64.8675
# epoch: 19000, loss_train = 21.3337, loss_test = 62.7545
# epoch: 19100, loss_train = 21.3099, loss_test = 60.7118
# epoch: 19200, loss_train = 21.2869, loss_test = 58.7364
# epoch: 19300, loss_train = 21.2647, loss_test = 56.8287
# epoch: 19400, loss_train = 21.2432, loss_test = 54.9840
# epoch: 19500, loss_train = 21.2225, loss_test = 53.1994
# epoch: 19600, loss_train = 21.2025, loss_test = 51.4768
# epoch: 19700, loss_train = 21.1831, loss_test = 49.8091
# epoch: 19800, loss_train = 21.1645, loss_test = 48.1991
# epoch: 19900, loss_train = 21.1465, loss_test = 46.6414
# epoch: 20000, loss_train = 21.1291, loss_test = 45.1363
# epoch: 20100, loss_train = 21.1122, loss_test = 43.6794
# epoch: 20200, loss_train = 21.0960, loss_test = 42.2741
# epoch: 20300, loss_train = 21.0803, loss_test = 40.9132
# epoch: 20400, loss_train = 21.0652, loss_test = 39.5983
# epoch: 20500, loss_train = 21.0506, loss_test = 38.3269
# epoch: 20600, loss_train = 21.0365, loss_test = 37.0970
# epoch: 20700, loss_train = 21.0228, loss_test = 35.9090
# epoch: 20800, loss_train = 21.0097, loss_test = 34.7603
# epoch: 20900, loss_train = 20.9969, loss_test = 33.6489
# epoch: 21000, loss_train = 20.9846, loss_test = 32.5735
# epoch: 21100, loss_train = 20.9728, loss_test = 31.5358
# epoch: 21200, loss_train = 20.9613, loss_test = 30.5322
# epoch: 21300, loss_train = 20.9503, loss_test = 29.5611
# epoch: 21400, loss_train = 20.9396, loss_test = 28.6216
# epoch: 21500, loss_train = 20.9293, loss_test = 27.7129
# epoch: 21600, loss_train = 20.9193, loss_test = 26.8344
# epoch: 21700, loss_train = 20.9097, loss_test = 25.9856
# epoch: 21800, loss_train = 20.9004, loss_test = 25.1643
# epoch: 21900, loss_train = 20.8914, loss_test = 24.3702
# epoch: 22000, loss_train = 20.8828, loss_test = 23.6026
# epoch: 22100, loss_train = 20.8744, loss_test = 22.8596
# epoch: 22200, loss_train = 20.8663, loss_test = 22.1412
# epoch: 22300, loss_train = 20.8585, loss_test = 21.4463
# epoch: 22400, loss_train = 20.8510, loss_test = 20.7744
# epoch: 22500, loss_train = 20.8437, loss_test = 20.1242
# epoch: 22600, loss_train = 20.8366, loss_test = 19.4951
# epoch: 22700, loss_train = 20.8298, loss_test = 18.8867
# epoch: 22800, loss_train = 20.8233, loss_test = 18.2980
# epoch: 22900, loss_train = 20.8170, loss_test = 17.7298
# epoch: 23000, loss_train = 20.8109, loss_test = 17.1800
# epoch: 23100, loss_train = 20.8049, loss_test = 16.6478
# epoch: 23200, loss_train = 20.7992, loss_test = 16.1327
# epoch: 23300, loss_train = 20.7937, loss_test = 15.6340
# epoch: 23400, loss_train = 20.7884, loss_test = 15.1511
# epoch: 23500, loss_train = 20.7833, loss_test = 14.6850
# epoch: 23600, loss_train = 20.7783, loss_test = 14.2345
# epoch: 23700, loss_train = 20.7735, loss_test = 13.7982
# epoch: 23800, loss_train = 20.7689, loss_test = 13.3753
# epoch: 23900, loss_train = 20.7644, loss_test = 12.9658
# epoch: 24000, loss_train = 20.7601, loss_test = 12.5715
# epoch: 24100, loss_train = 20.7559, loss_test = 12.1889
# epoch: 24200, loss_train = 20.7519, loss_test = 11.8179
# epoch: 24300, loss_train = 20.7480, loss_test = 11.4598
# epoch: 24400, loss_train = 20.7443, loss_test = 11.1137
# epoch: 24500, loss_train = 20.7406, loss_test = 10.7776
# epoch: 24600, loss_train = 20.7371, loss_test = 10.4527
# epoch: 24700, loss_train = 20.7338, loss_test = 10.1391
# epoch: 24800, loss_train = 20.7305, loss_test = 9.8340
# epoch: 24900, loss_train = 20.7273, loss_test = 9.5400
# epoch: 25000, loss_train = 20.7243, loss_test = 9.2555
# weight tensor([[ 2.0145, -0.9842]])
# bias tensor([59.1002])
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8896f6cb-f067-4e43-9e5a-36f1eeead8c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8896f6cb-f067-4e43-9e5a-36f1eeead8c2")) {                    Plotly.newPlot(                        "8896f6cb-f067-4e43-9e5a-36f1eeead8c2",                        [{"hovertemplate":"variable=loss_test<br>epoch=%{x}<br>value=%{y}<extra></extra>","legendgroup":"loss_test","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"loss_test","showlegend":true,"x":[9.0,19.0,29.0,39.0,49.0,59.0,69.0,79.0,89.0,99.0,109.0,119.0,129.0,139.0,149.0,159.0,169.0,179.0,189.0,199.0,209.0,219.0,229.0,239.0,249.0,259.0,269.0,279.0,289.0,299.0,309.0,319.0,329.0,339.0,349.0,359.0,369.0,379.0,389.0,399.0,409.0,419.0,429.0,439.0,449.0,459.0,469.0,479.0,489.0,499.0,509.0,519.0,529.0,539.0,549.0,559.0,569.0,579.0,589.0,599.0,609.0,619.0,629.0,639.0,649.0,659.0,669.0,679.0,689.0,699.0,709.0,719.0,729.0,739.0,749.0,759.0,769.0,779.0,789.0,799.0,809.0,819.0,829.0,839.0,849.0,859.0,869.0,879.0,889.0,899.0,909.0,919.0,929.0,939.0,949.0,959.0,969.0,979.0,989.0,999.0,1009.0,1019.0,1029.0,1039.0,1049.0,1059.0,1069.0,1079.0,1089.0,1099.0,1109.0,1119.0,1129.0,1139.0,1149.0,1159.0,1169.0,1179.0,1189.0,1199.0,1209.0,1219.0,1229.0,1239.0,1249.0,1259.0,1269.0,1279.0,1289.0,1299.0,1309.0,1319.0,1329.0,1339.0,1349.0,1359.0,1369.0,1379.0,1389.0,1399.0,1409.0,1419.0,1429.0,1439.0,1449.0,1459.0,1469.0,1479.0,1489.0,1499.0,1509.0,1519.0,1529.0,1539.0,1549.0,1559.0,1569.0,1579.0,1589.0,1599.0,1609.0,1619.0,1629.0,1639.0,1649.0,1659.0,1669.0,1679.0,1689.0,1699.0,1709.0,1719.0,1729.0,1739.0,1749.0,1759.0,1769.0,1779.0,1789.0,1799.0,1809.0,1819.0,1829.0,1839.0,1849.0,1859.0,1869.0,1879.0,1889.0,1899.0,1909.0,1919.0,1929.0,1939.0,1949.0,1959.0,1969.0,1979.0,1989.0,1999.0,2009.0,2019.0,2029.0,2039.0,2049.0,2059.0,2069.0,2079.0,2089.0,2099.0,2109.0,2119.0,2129.0,2139.0,2149.0,2159.0,2169.0,2179.0,2189.0,2199.0,2209.0,2219.0,2229.0,2239.0,2249.0,2259.0,2269.0,2279.0,2289.0,2299.0,2309.0,2319.0,2329.0,2339.0,2349.0,2359.0,2369.0,2379.0,2389.0,2399.0,2409.0,2419.0,2429.0,2439.0,2449.0,2459.0,2469.0,2479.0,2489.0,2499.0,2509.0,2519.0,2529.0,2539.0,2549.0,2559.0,2569.0,2579.0,2589.0,2599.0,2609.0,2619.0,2629.0,2639.0,2649.0,2659.0,2669.0,2679.0,2689.0,2699.0,2709.0,2719.0,2729.0,2739.0,2749.0,2759.0,2769.0,2779.0,2789.0,2799.0,2809.0,2819.0,2829.0,2839.0,2849.0,2859.0,2869.0,2879.0,2889.0,2899.0,2909.0,2919.0,2929.0,2939.0,2949.0,2959.0,2969.0,2979.0,2989.0,2999.0,3009.0,3019.0,3029.0,3039.0,3049.0,3059.0,3069.0,3079.0,3089.0,3099.0,3109.0,3119.0,3129.0,3139.0,3149.0,3159.0,3169.0,3179.0,3189.0,3199.0,3209.0,3219.0,3229.0,3239.0,3249.0,3259.0,3269.0,3279.0,3289.0,3299.0,3309.0,3319.0,3329.0,3339.0,3349.0,3359.0,3369.0,3379.0,3389.0,3399.0,3409.0,3419.0,3429.0,3439.0,3449.0,3459.0,3469.0,3479.0,3489.0,3499.0,3509.0,3519.0,3529.0,3539.0,3549.0,3559.0,3569.0,3579.0,3589.0,3599.0,3609.0,3619.0,3629.0,3639.0,3649.0,3659.0,3669.0,3679.0,3689.0,3699.0,3709.0,3719.0,3729.0,3739.0,3749.0,3759.0,3769.0,3779.0,3789.0,3799.0,3809.0,3819.0,3829.0,3839.0,3849.0,3859.0,3869.0,3879.0,3889.0,3899.0,3909.0,3919.0,3929.0,3939.0,3949.0,3959.0,3969.0,3979.0,3989.0,3999.0,4009.0,4019.0,4029.0,4039.0,4049.0,4059.0,4069.0,4079.0,4089.0,4099.0,4109.0,4119.0,4129.0,4139.0,4149.0,4159.0,4169.0,4179.0,4189.0,4199.0,4209.0,4219.0,4229.0,4239.0,4249.0,4259.0,4269.0,4279.0,4289.0,4299.0,4309.0,4319.0,4329.0,4339.0,4349.0,4359.0,4369.0,4379.0,4389.0,4399.0,4409.0,4419.0,4429.0,4439.0,4449.0,4459.0,4469.0,4479.0,4489.0,4499.0,4509.0,4519.0,4529.0,4539.0,4549.0,4559.0,4569.0,4579.0,4589.0,4599.0,4609.0,4619.0,4629.0,4639.0,4649.0,4659.0,4669.0,4679.0,4689.0,4699.0,4709.0,4719.0,4729.0,4739.0,4749.0,475 ...

# %% [markdown]
# **Aufgabe 1.7 (PyTorch)** | Abschließend sollen Sie versuchen, das obige Beispiel durch einfache Veränderungen deutlich schneller Trainieren zu.
#
# Dazu könnten folgende verändert werden.
# - `learning_rate` anpassen
# - anderen Optimierer testen, z.B. Adam
# - Input normieren
# - Verändern Sie auch den Parameter $t$

# %%
# Normierung der Inputdaten → Training läuft deutlich schneller ab. SGD ist auch bei großen 't' werten stabil
# Beispiel: 
m,s = X_train.mean(), X_train.std()
X_train = (X_train - m) / s
X_test = (X_test - m) / s

# Adam, trainiert auch bei großen 't' werten stabil
# In diesem Fall kann bei Adam die lerning_rate sehr hoch gesetzt werden, ohne dass das Training instabil verläuft.
